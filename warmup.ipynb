# %%
# Import pandas & numpy
# 
import pandas as pd 
import numpy as np

# read the file (CSV)
sales_df = pd.read_csv('data/sales_transactions.csv')
print(sales_df)
# Out:
#     account           name  order       sku  quantity  unit price  ext price
# 0    383080       Will LLC  10001  B1-20000         7       33.69     235.83
# 1    383080       Will LLC  10001  S1-27722        11       21.12     232.32
# 2    383080       Will LLC  10001  B1-86481         3       35.99     107.97
# 3    412290  Jerde-Hilpert  10005  S1-06532        48       55.82    2679.36
# 4    412290  Jerde-Hilpert  10005  S1-82801        21       13.62     286.02
# 5    412290  Jerde-Hilpert  10005  S1-06532         9       92.55     832.95
# 6    412290  Jerde-Hilpert  10005  S1-47412        44       78.91    3472.04
# 7    412290  Jerde-Hilpert  10005  S1-27722        36       25.42     915.12
# 8    218895      Kulas Inc  10006  S1-27722        32       95.66    3061.12
# 9    218895      Kulas Inc  10006  B1-33087        23       22.55     518.65
# 10   218895      Kulas Inc  10006  B1-33364         3       72.30     216.90
# 11   218895      Kulas Inc  10006  B1-20000        -1       72.18     -72.18

# %%
# Look at the descriptive statistics
print(sales_df.head())
# Out:
#    account           name  order       sku  quantity  unit price  ext price
# 0   383080       Will LLC  10001  B1-20000         7       33.69     235.83
# 1   383080       Will LLC  10001  S1-27722        11       21.12     232.32
# 2   383080       Will LLC  10001  B1-86481         3       35.99     107.97
# 3   412290  Jerde-Hilpert  10005  S1-06532        48       55.82    2679.36
# 4   412290  Jerde-Hilpert  10005  S1-82801        21       13.62     286.02

# %%
print(sales_df.tail())
# Out:
#     account           name  order       sku  quantity  unit price  ext price
# 7    412290  Jerde-Hilpert  10005  S1-27722        36       25.42     915.12
# 8    218895      Kulas Inc  10006  S1-27722        32       95.66    3061.12
# 9    218895      Kulas Inc  10006  B1-33087        23       22.55     518.65
# 10   218895      Kulas Inc  10006  B1-33364         3       72.30     216.90
# 11   218895      Kulas Inc  10006  B1-20000        -1       72.18     -72.18

# %%
# look at the descriptive statistics
print(sales_df.describe())
# Out:
#              account         order   quantity  unit price    ext price
# count      12.000000     12.000000  12.000000   12.000000    12.000000
# mean   340522.500000  10004.333333  19.666667   51.650833  1040.508333
# std     90633.772416      2.059715  16.945546   29.694003  1267.357787
# min    218895.000000  10001.000000  -1.000000   13.620000   -72.180000
# 25%    218895.000000  10004.000000   6.000000   24.702500   228.465000
# 50%    383080.000000  10005.000000  16.000000   45.905000   402.335000
# 75%    412290.000000  10006.000000  33.000000   73.952500  1356.180000
# max    412290.000000  10006.000000  48.000000   95.660000  3472.040000

# %%
# Look at the shape of our data
rows = sales_df.shape[0]
columns = sales_df.shape[1]
print('Rows: ', rows)
print('Columns: ', columns)
# Out:
# Rows:  12
# Columns:  7

# %%
# Shape
rows, cols = sales_df.shape
print(f'Rows: {rows}, Columns {cols}')
# Out:
# Rows: 12, Columns 7

# %%
# look at the dtypes
print(sales_df.dtypes)
# Out:
# account         int64
# name              str
# order           int64
# sku               str
# quantity        int64
# unit price    float64
# ext price     float64
# dtype: object

# %%
# num of non null values
print(sales_df.count())
# Out:
# account       12
# name          12
# order         12
# sku           12
# quantity      12
# unit price    12
# ext price     12
# dtype: int64

# %%
# check for null or missing values
print(sales_df.isnull().sum())
# Out:
# account       0
# name          0
# order         0
# sku           0
# quantity      0
# unit price    0
# ext price     0
# dtype: int64

# %%
print(sales_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   account     12 non-null     int64
#  1   name        12 non-null     str
#  2   order       12 non-null     int64
#  3   sku         12 non-null     str
#  4   quantity    12 non-null     int64
#  5   unit price  12 non-null     float64
#  6   ext price   12 non-null     float64
# dtypes: float64(2), int64(3), str(2)
# memory usage: 804.0 bytes
# None

# %%
print(f'Num of dups: ', sales_df.duplicated().sum())
# Out:
# Num of dups:  0
