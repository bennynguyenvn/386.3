# %% [markdown]
# # STUDENT INFO INITIAL LOOK

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Load the data
df = pd.read_csv('data/RTT_36_data.csv')
df
# Out:
#     ID       Start time  Completion time      Email  Name  Last modified time  \
# 0    1  8/4/26 11:47:47  8/4/26 11:53:02  anonymous   NaN                 NaN
# 1    2  8/4/26 11:48:01  8/4/26 11:53:11  anonymous   NaN                 NaN
# 2    3  8/4/26 11:47:53  8/4/26 11:53:12  anonymous   NaN                 NaN
# 3    4  8/4/26 11:48:01  8/4/26 11:54:22  anonymous   NaN                 NaN
# 4    5  8/4/26 11:48:32  8/4/26 11:54:34  anonymous   NaN                 NaN
# 5    6  8/4/26 11:47:42  8/4/26 11:54:51  anonymous   NaN                 NaN
# 6    7  8/4/26 11:48:14  8/4/26 11:55:29  anonymous   NaN                 NaN
# 7    8  8/4/26 11:48:06  8/4/26 11:55:42  anonymous   NaN                 NaN
# 8    9  8/4/26 11:48:08  8/4/26 11:55:59  anonymous   NaN                 NaN
# 9   10  8/4/26 11:47:49  8/4/26 11:56:16  anonymous   NaN                 NaN
# 10  11  8/4/26 11:48:47  8/4/26 11:56:51  anonymous   NaN                 NaN
# ...

# %%
# Data initial look
rows, cols = df.shape
print(f'Rows: {rows}')
print(f'Cols: {cols}')
# Out:
# Rows: 29
# Cols: 55

# %%
df.head()
# Out:
#    ID       Start time  Completion time      Email  Name  Last modified time  \
# 0   1  8/4/26 11:47:47  8/4/26 11:53:02  anonymous   NaN                 NaN
# 1   2  8/4/26 11:48:01  8/4/26 11:53:11  anonymous   NaN                 NaN
# 2   3  8/4/26 11:47:53  8/4/26 11:53:12  anonymous   NaN                 NaN
# 3   4  8/4/26 11:48:01  8/4/26 11:54:22  anonymous   NaN                 NaN
# 4   5  8/4/26 11:48:32  8/4/26 11:54:34  anonymous   NaN                 NaN
#
#   What is your cohort number? What month did your cohort start?  \
# 0                 2026-RTT-36                            August
# 1                 2026 RTT-36                            August
# 2                          36                            August
# 3                 2026-rtt-36                            August
# 4                 2026-RTT-36                            August
#
#    What year is it?  What is your age?  ...  \
# 0              2026                 36  ...
# ...

# %%
df.tail()
# Out:
#     ID       Start time  Completion time      Email  Name  Last modified time  \
# 24  25  8/4/26 11:47:52  8/4/26 12:17:23  anonymous   NaN                 NaN
# 25  26  8/4/26 11:48:02  8/4/26 12:38:12  anonymous   NaN                 NaN
# 26  27  8/4/26 11:47:50  8/4/26 12:50:19  anonymous   NaN                 NaN
# 27  28  8/4/26 12:58:33  8/4/26 13:01:35  anonymous   NaN                 NaN
# 28  29  8/4/26 13:07:43  8/4/26 13:14:10  anonymous   NaN                 NaN
#
#    What is your cohort number? What month did your cohort start?  \
# 24                  2026-RT-36                            August
# 25                 2026-RTT-36                            August
# 26                 2026-rtt-36                            August
# 27                      RTT-36                            August
# 28                 2026-RTT-36                            August
#
#     What year is it?  What is your age?  ...  \
# 24              2026                 44  ...
# ...

# %%
df.describe()
# Out:
#               ID  Name  Last modified time  What year is it?  \
# count  29.000000   0.0                 0.0              29.0
# mean   15.000000   NaN                 NaN            2026.0
# std     8.514693   NaN                 NaN               0.0
# min     1.000000   NaN                 NaN            2026.0
# 25%     8.000000   NaN                 NaN            2026.0
# 50%    15.000000   NaN                 NaN            2026.0
# 75%    22.000000   NaN                 NaN            2026.0
# max    29.000000   NaN                 NaN            2026.0
#
#        What is your age?  How many siblings do you have?  \
# count          29.000000                       29.000000
# mean           37.172414                        2.655172
# std             8.705782                        2.635958
# min            19.000000                        0.000000
# 25%            32.000000                        1.000000
# 50%            38.000000                        2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 55 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   ID                                                                              29 non-null     int64
#  1   Start time                                                                      29 non-null     str
#  2   Completion time                                                                 29 non-null     str
#  3   Email                                                                           29 non-null     str
#  4   Name                                                                            0 non-null      float64
#  5   Last modified time                                                              0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                                                                                 0
# Start time                                                                         0
# Completion time                                                                    0
# Email                                                                              0
# Name                                                                              29
# Last modified time                                                                29
# What is your cohort number?                                                        0
# What month did your cohort start?                                                  0
# What year is it?                                                                   0
# What is your age?                                                                  0
# What is your gender?                                                               0
# ...

# %%
qual_cols = df.select_dtypes(
    include=['object','string','category','bool']
)
print(qual_cols)
# Out:
#          Start time  Completion time      Email What is your cohort number?  \
# 0   8/4/26 11:47:47  8/4/26 11:53:02  anonymous                 2026-RTT-36
# 1   8/4/26 11:48:01  8/4/26 11:53:11  anonymous                 2026 RTT-36
# 2   8/4/26 11:47:53  8/4/26 11:53:12  anonymous                          36
# 3   8/4/26 11:48:01  8/4/26 11:54:22  anonymous                 2026-rtt-36
# 4   8/4/26 11:48:32  8/4/26 11:54:34  anonymous                 2026-RTT-36
# 5   8/4/26 11:47:42  8/4/26 11:54:51  anonymous              2026 - RTT -36
# 6   8/4/26 11:48:14  8/4/26 11:55:29  anonymous                          36
# 7   8/4/26 11:48:06  8/4/26 11:55:42  anonymous                 2026-RTT-36
# 8   8/4/26 11:48:08  8/4/26 11:55:59  anonymous                          36
# 9   8/4/26 11:47:49  8/4/26 11:56:16  anonymous                      RTT-36
# 10  8/4/26 11:48:47  8/4/26 11:56:51  anonymous                 2026-RTT-36
# ...

# %%
print(f'Duplicate records: {df.duplicated().sum()}')
# Out:
# Duplicate records: 0

# %%
number_cols=df.select_dtypes(
    include=['number']
).columns.tolist()
print(number_cols)
# Out:
# ['ID', 'Name', 'Last modified time', 'What year is it?', 'What is your age?', 'How many siblings do you have?', 'How comfortable are you learning new technology?', 'Does pineapple belong on pizza?']
