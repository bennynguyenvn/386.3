# %% [markdown]
# ### Pandas Notes

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Pandas DataTypes
# - series(s) - single dimensional array. Single column
#     - Homogenous - 1 data type per series
# - dataframe(df) - two dimensional array (table)

# %%
ser = pd.Series(list('abcdef'))

# give it a name
ser.name = 'alphabet'


# .head(n) - show top 5 records (n = number of records)
print(ser.head(2))

# .tail(n) - show top 5 records (n = number of records)
print(ser.tail(2))
# Out:
# 0    a
# 1    b
# Name: alphabet, dtype: str
# 4    e
# 5    f
# Name: alphabet, dtype: str

# %% [markdown]
# #### Working with DataFrames and JSON

# %%
cars_df = pd.read_json('data/cars.json')

# Look at the first and last 5 entries

# %%
# Look at the descriptive statistics
print(cars_df.head())
# Out:
#                           Car   MPG  Cylinders  Displacement  Horsepower  \
# 0              Chevrolet Vega  25.0          4         140.0          75
# 1         Chevrolet Vega (sw)  22.0          4         140.0          72
# 2         Chevrolet Vega 2300  28.0          4         140.0          90
# 3             Chevrolet Woody  24.5          4          98.0          60
# 4  Chevrolete Chevelle Malibu  16.0          6         250.0         105
#
#    Weight  Acceleration  Model Origin  quantity     city
# 0    2542          17.0     74     US       177       NJ
# 1    2408          19.0     71     US        91   DALLAS
# 2    2264          15.5     71     US        74    TEXAS
# 3    2164          22.1     76     US       241       OH
# 4    3897          18.5     75     US       206  NewYork

# %%
print(cars_df.tail())
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 156         Mercury Capri v6  21.0          6         155.0         107
# 157  Mercury Cougar Brougham  15.0          8         302.0         130
# 158    Mercury Grand Marquis  16.5          8         351.0         138
# 159           Mercury Lynx l  36.0          4          98.0          70
# 160          Mercury Marquis  11.0          8         429.0         208
#
#      Weight  Acceleration  Model Origin  quantity     city
# 156    2472          14.0     73     US       158  NewYork
# 157    4295          14.9     77     US        27       NJ
# 158    3955          13.2     79     US       332   DALLAS
# 159    2125          17.3     82     US       425    TEXAS
# 160    4633          11.0     72     US       112       OH

# %%
# look at the descriptive statistics
print(cars_df.describe())
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  161.000000  161.000000    161.000000  161.000000   161.000000
# mean    23.801863    5.347826    185.232919  100.664596  2915.093168
# std      8.810125    1.761607    105.394809   41.079640   890.293883
# min      0.000000    3.000000     68.000000    0.000000  1613.000000
# 25%     17.000000    4.000000     98.000000   72.000000  2130.000000
# 50%     24.000000    4.000000    140.000000   88.000000  2625.000000
# 75%     31.000000    8.000000    302.000000  130.000000  3620.000000
# max     46.600000    8.000000    440.000000  215.000000  4955.000000
#
#        Acceleration       Model    quantity
# count    161.000000  161.000000  161.000000
# mean      15.509938   76.260870  224.875776
# std        2.515780    3.818576  127.741084
# min        8.000000   70.000000    5.000000
# 25%       14.000000   73.000000  112.000000
# 50%       15.500000   76.000000  227.000000
# ...

# %%
# Look at the shape of our data
rows = cars_df.shape[0]
columns = cars_df.shape[1]
print('Rows: ', rows)
print('Columns: ', columns)
# Out:
# Rows:  161
# Columns:  11

# %%
# look at the dtypes
print(cars_df.dtypes)
# Out:
# Car                 str
# MPG             float64
# Cylinders         int64
# Displacement    float64
# Horsepower        int64
# Weight            int64
# Acceleration    float64
# Model             int64
# Origin              str
# quantity          int64
# city                str
# dtype: object

# %%
# num of non null values
print(cars_df.count())
# Out:
# Car             161
# MPG             161
# Cylinders       161
# Displacement    161
# Horsepower      161
# Weight          161
# Acceleration    161
# Model           161
# Origin          161
# quantity        161
# city            161
# dtype: int64

# %%
# check for null or missing values
print(cars_df.isnull().sum())
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# quantity        0
# city            0
# dtype: int64

# %%
print(cars_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           161 non-null    str
#  1   MPG           161 non-null    float64
#  2   Cylinders     161 non-null    int64
#  3   Displacement  161 non-null    float64
#  4   Horsepower    161 non-null    int64
#  5   Weight        161 non-null    int64
#  6   Acceleration  161 non-null    float64
#  7   Model         161 non-null    int64
#  8   Origin        161 non-null    str
#  9   quantity      161 non-null    int64
#  10  city          161 non-null    str
# dtypes: float64(3), int64(5), str(3)
# memory usage: 14.0 KB
# None

# %%
# value counts & values
# print(cars_df['Car'].value_counts())
print(cars_df['city'].value_counts())
# Out:
# city
# NewYork    36
# NJ         35
# DALLAS     33
# TEXAS      30
# OH         27
# Name: count, dtype: int64

# %%
# accessing single values


# .at() label based
print(cars_df.at[143, 'Car'])

# .iat() index based
print(cars_df.iat[143,0])
# Out:
# Mazda GLC 4
# Mazda GLC 4

# %%
# Scenario: You need to loop over each column and perform an action on it
print(cars_df.columns)
print(cars_df.columns[0])
print(cars_df.columns[1])

# turn columns into iterable list
print(cars_df.columns.tolist())
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin', 'quantity', 'city'],
#       dtype='str')
# Car
# MPG
# ['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model', 'Origin', 'quantity', 'city']

# %%
print(cars_df.axes)
# Out:
# [RangeIndex(start=0, stop=161, step=1), Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin', 'quantity', 'city'],
#       dtype='str')]

# %%
print(len(cars_df.axes[0]))
# Out:
# 161

# %% [markdown]
# #### Handling CSV's with Pandas

# %%
e_df = pd.read_csv("data/employee.csv")
print(e_df)
# Out:
#         Name   Age  Weight     Salary
# 0      James  36.0    75.0  5428000.0
# 1    Villers  38.0    74.0  3428000.0
# 2      VKole  31.0    70.0  8428000.0
# 3      Smith  34.0    80.0  4428000.0
# 4      Gayle  40.0   100.0  4528000.0
# 5       Adam  40.0     NaN  4528000.0
# 6     Rooter  33.0    72.0  7028000.0
# 7   Peterson  42.0    85.0  2528000.0
# 8      lynda  42.0    85.0        NaN
# 9        NaN  42.0    85.0        NaN
# 10     Jenny   NaN   100.0    25632.0
# 11      Kenn   NaN   110.0    25632.0
# 12       Aly   NaN    90.0    25582.0
# 13      John  41.0    85.0  1528000.0
# 14       Ali  26.0    69.0        NaN

# %%
# read_csv into a df

# %%
#print the shape
rows = e_df.shape[0]
columns = e_df.shape[1]
print('Rows: ', rows)
print('Columns: ', columns)
# Out:
# Rows:  15
# Columns:  4

# %%
# look at the first 5 and last 5 records
print(e_df.head())

print(e_df.tail())
# Out:
#       Name   Age  Weight     Salary
# 0    James  36.0    75.0  5428000.0
# 1  Villers  38.0    74.0  3428000.0
# 2    VKole  31.0    70.0  8428000.0
# 3    Smith  34.0    80.0  4428000.0
# 4    Gayle  40.0   100.0  4528000.0
#      Name   Age  Weight     Salary
# 10  Jenny   NaN   100.0    25632.0
# 11   Kenn   NaN   110.0    25632.0
# 12    Aly   NaN    90.0    25582.0
# 13   John  41.0    85.0  1528000.0
# 14    Ali  26.0    69.0        NaN

# %%
# Look at data types
print(e_df.dtypes)
# Out:
# Name          str
# Age       float64
# Weight    float64
# Salary    float64
# dtype: object

# %%
# look at descriptive statistics
print(e_df.describe())
# Out:
#              Age      Weight        Salary
# count  12.000000   14.000000  1.200000e+01
# mean   37.083333   84.285714  3.494070e+06
# std     5.160309   12.368873  2.771220e+06
# min    26.000000   69.000000  2.558200e+04
# 25%    33.750000   74.250000  1.152408e+06
# 50%    39.000000   85.000000  3.928000e+06
# 75%    41.250000   88.750000  4.753000e+06
# max    42.000000  110.000000  8.428000e+06

# %%
# num of non null values
print(e_df.count())
# Out:
# Name      14
# Age       12
# Weight    14
# Salary    12
# dtype: int64

# %%
# check for null or missing values
print(e_df.isnull().sum())
# Out:
# Name      1
# Age       3
# Weight    1
# Salary    3
# dtype: int64

# %%
# Info & values counts
print(e_df.info())

print(e_df['Age'].value_counts())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    14 non-null     str
#  1   Age     12 non-null     float64
#  2   Weight  14 non-null     float64
#  3   Salary  12 non-null     float64
# dtypes: float64(3), str(1)
# memory usage: 612.0 bytes
# None
# Age
# 42.0    3
# 40.0    2
# 36.0    1
# 38.0    1
# 31.0    1
# 34.0    1
# 33.0    1
# 41.0    1
# 26.0    1
# Name: count, dtype: int64

# %% [markdown]
# ### Handling hand Manipulating DF Columns
# - `df.columns` - give us an series of column names
# - `df.columns[n]` - get specific column names using index number
# - `df.columns[[0,3,4]]` - get multi columns based on multi indexes

# %%
print(cars_df.columns[0])
print(cars_df.columns[[0,2,5]])
# Out:
# Car
# Index(['Car', 'Cylinders', 'Weight'], dtype='str')

# %% [markdown]
# #### Selecting Columns
# - `df['ColName']` - selecting column using label
# - `df[['col1', 'col2']]` - selecting multi columns using labels

# %%
cars_df['Car']
# Out:
# 0                  Chevrolet Vega
# 1             Chevrolet Vega (sw)
# 2             Chevrolet Vega 2300
# 3                 Chevrolet Woody
# 4      Chevrolete Chevelle Malibu
#                   ...
# 156              Mercury Capri v6
# 157       Mercury Cougar Brougham
# 158         Mercury Grand Marquis
# 159                Mercury Lynx l
# 160               Mercury Marquis
# Name: Car, Length: 161, dtype: str

# %%
print(cars_df[cars_df.columns[0]])
# Out:
# 0                  Chevrolet Vega
# 1             Chevrolet Vega (sw)
# 2             Chevrolet Vega 2300
# 3                 Chevrolet Woody
# 4      Chevrolete Chevelle Malibu
#                   ...
# 156              Mercury Capri v6
# 157       Mercury Cougar Brougham
# 158         Mercury Grand Marquis
# 159                Mercury Lynx l
# 160               Mercury Marquis
# Name: Car, Length: 161, dtype: str

# %%
print(cars_df.head())
subset = cars_df[['MPG','Cylinders','Displacement']]
# Out:
#                           Car   MPG  Cylinders  Displacement  Horsepower  \
# 0              Chevrolet Vega  25.0          4         140.0          75
# 1         Chevrolet Vega (sw)  22.0          4         140.0          72
# 2         Chevrolet Vega 2300  28.0          4         140.0          90
# 3             Chevrolet Woody  24.5          4          98.0          60
# 4  Chevrolete Chevelle Malibu  16.0          6         250.0         105
#
#    Weight  Acceleration  Model Origin  quantity     city
# 0    2542          17.0     74     US       177       NJ
# 1    2408          19.0     71     US        91   DALLAS
# 2    2264          15.5     71     US        74    TEXAS
# 3    2164          22.1     76     US       241       OH
# 4    3897          18.5     75     US       206  NewYork

# %%
print(subset)
# Out:
#       MPG  Cylinders  Displacement
# 0    25.0          4         140.0
# 1    22.0          4         140.0
# 2    28.0          4         140.0
# 3    24.5          4          98.0
# 4    16.0          6         250.0
# ..    ...        ...           ...
# 156  21.0          6         155.0
# 157  15.0          8         302.0
# 158  16.5          8         351.0
# 159  36.0          4          98.0
# 160  11.0          8         429.0
#
# [161 rows x 3 columns]

# %%
print(cars_df.Car.values)
# Out:
# <StringArray>
# [            'Chevrolet Vega',        'Chevrolet Vega (sw)',
#         'Chevrolet Vega 2300',            'Chevrolet Woody',
#  'Chevrolete Chevelle Malibu',                  'Chevy C20',
#                  'Chevy S-10',           'Chrysler Cordoba',
#  'Chrysler Lebaron Medallion',     'Chrysler Lebaron Salon',
#  ...
#               'Mazda RX-7 GS',         'Mercedes Benz 300d',
#          'Mercedes-Benz 240d',         'Mercedes-Benz 280s',
#          'Mercury Capri 2000',           'Mercury Capri v6',
#     'Mercury Cougar Brougham',      'Mercury Grand Marquis',
#              'Mercury Lynx l',            'Mercury Marquis']
# Length: 161, dtype: str

# %%
calories = {
    'day1': 2200,
    'day2': 2580,
    'day3': 2700
}

index = ['day1','day2']

calories_series = pd.Series(calories, index=index)

print(calories_series)

day_index_info = calories_series.index.tolist()
# Out:
# day1    2200
# day2    2580
# dtype: int64

# %%
index_list = cars_index.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 index_list = cars_index.tolist()
#
# NameError: name 'cars_index' is not defined
